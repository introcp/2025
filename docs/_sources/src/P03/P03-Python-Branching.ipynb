# %% [markdown]
# <div align="center">
#
# # <b style="font-family: 'LUISS', 'Lato'">Branching</b>
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2>
#
# <h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3>
# <img src="https://introcp.github.io/dist/img/cliente-luiss.png">
#
# <br><br><br>
#
# </div>

# %% [markdown]
# ## Branching
#
# <div style="display: flex; justify-content: space-around;">
#   <div style="text-align: center;">
#     <p>A program <b style="color:red">without branching</b></p>
#     <img src="https://introcp.github.io/src/P03/img/Branching1.png" style="height: 400px;">
#   </div>
#   <div style="text-align: center;">
#     <p>A program <b style="color:red">with branching</b></p>
#     <img src="https://introcp.github.io/src/P03/img/Branching2.png" style="height: 400px;">
#   </div>
# </div>

# %% [markdown]
# ## Branching in Python
#
# <div style="display: flex; column-gap: 50px; ">
#   <div style="width: 200px;">
#     <b>Plain if</b>
#     <pre><code>if &lt;condition&gt;:
#     statement
#     statement
#     ...</code></pre>
#   </div>
#   <div style="width: 200px;">
#     <b>if-else</b>
#     <pre><code>if &lt;condition&gt;:
#     statement
#     ...
# else:
#     statement
#     ...</code></pre>
#   </div>
#   <div style="width: 200px;">
#     <b>if-elif-else</b>
#     <pre><code>if &lt;condition&gt;:
#     statement
#     ...
# elif &lt;condition&gt;:
#     statement
#     ...
# else:
#     statement
#     ...</code></pre>
#   </div>
# </div>
#
# - `<condition>` yields `True` or `False`
# - Evaluate statements in that block if `<condition>` is `True`
# - Indentation is the key to delimit blocks
# - Place `:` at the end of `<condition>`

# %% [markdown]
# ## Examples: if

# %%
num = 3
if num > 0:
    print(num, "is a positive number.")
print("This is always printed. It's outside of the block.")
# Out:
# 3 is a positive number.
# This is always printed. It's outside of the block.

# %% [markdown]
# <br>

# %%
num = -1
if num > 0:
    print(num, "is a positive number.")
print("This is always printed. It's outside of the block.")
# Out:
# This is always printed. It's outside of the block.

# %% [markdown]
# ## Flowchart of an `if` statement
#
# Logical flowchart of an if statement:
# <div align="center">
#     <img src="https://introcp.github.io/src/P03/img/branching-if.png" style="height: 400px;">
# </div>

# %% [markdown]
# ## Examples: if-else

# %%
num = 1
if num >= 0:
    print("Number is positive or zero.")
else:
    print("Negative number.")
# Out:
# Number is positive or zero.

# %% [markdown]
# What happens with:
# - `num = 0`
# - `num = -5`
#
# ?

# %% [markdown]
# <br>

# %%
num = 0
if num >= 0:
    print("Number is positive or zero.")
else:
    print("Negative number.")
# Out:
# Number is positive or zero.

# %%
num = -5
if num >= 0:
    print("Number is positive or zero.")
else:
    print("Negative number.")
# Out:
# Negative number.

# %% [markdown]
# ## Flowchart of an `if-else` statement
#
# Logical flowchart of an if-else statement.:
# <div align="center">
#     <img src="https://introcp.github.io/src/P03/img/branching-if-else.png" style="height: 400px;">
# </div>

# %% [markdown]
# ## Examples: if-elif-else

# %%
num = 3.4
if num > 0:
    print("Number is positive.")
elif num == 0:
    print("Number is zero.")
else:
    print("Number is negative.")
# Out:
# Number is positive.

# %% [markdown]
# What happens with:
# - `num = 0`
# - `num = -4.5`
#
# ?

# %% [markdown]
# <br>

# %%
num = 0
if num > 0:
    print("Number is positive.")
elif num == 0:
    print("Number is zero.")
else:
    print("Number is negative.")
# Out:
# Number is zero.

# %%
num = -4.5
if num > 0:
    print("Number is positive.")
elif num == 0:
    print("Number is zero.")
else:
    print("Number is negative.")
# Out:
# Number is negative.

# %% [markdown]
# ## Flowchart of an `if-elif-else` statement
#
# Logical flowchart of an if-elif-else statement:
# <div align="center">
#     <img src="https://introcp.github.io/src/P03/img/branching-if-elif-else.png" style="height: 400px;">
# </div>

# %% [markdown]
# ## Nested Statements
#
# Branching statements `if`, `else` and `elif` can be nested arbitrarily.

# %%
num = input()
num = float(num) # recall: input() returns a string
print("You entered: ", num)
if num >= 0:
    if num == 0:
        print("Number is zero")
    else:
        print("Number is positive")
else:
    print("Number is negative")
# Out:
# You entered:  10.0
# Number is positive

# %% [markdown]
# ## Indentation
#
# <div class="alert alert-block alert-info">
# <b>Recall</b>: Indentation (tab or 4 spaces) delimits blocks of code in Python.
# </div>

# %%
x = float(input("Enter a value for x: "))
y = float(input("Enter a value for y: "))
print("x is", x)
print("y is", y)
if x == y:
    print("y and x are equal")
    if y != 0:
        print("Finally, x/y is", x / y)
elif x > y:
    print("y is smaller")
else:
    print("x is smaller")
# Out:
# x is 10.0
# y is 20.0
# x is smaller

# %% [markdown]
# ## Exercise 1
#
# Write a piece of code that checks whether a number is even. If so, print a message.

# %% [markdown]
# A possible solution follows:

# %%
num = 42
if num % 2 == 0:
    print("Condition evaluates to True.")
    print("Number", num, "is even")
# Out:
# Condition evaluates to True.
# Number 42 is even

# %% [markdown]
# ## Exercise 2
#
# Write a piece of code that checks whether a number is even. Print a message about the outcome (odd or even).

# %% [markdown]
# A possible solution follows:

# %%
num = 42
if num % 2 == 0:
    print("Condition evaluates to True.")
    print("Number", num, "is even")
else:
    print("Condition evaluates to False.")
    print("Number", num, "is odd")
# Out:
# Condition evaluates to True.
# Number 42 is even

# %% [markdown]
# ## Exercise 3
#
# Write a piece of code that checks whether a number is odd or even. Assign a proper value (e.g., 'odd' or 'even') to a variable, depending on the outcome of the condition. Print the outcome at the end.

# %% [markdown]
# A possible solution follows:

# %%
num = 42
if num % 2 == 0:
    parity = "even"
else:
    parity = "odd"
print("Number", num, "is", parity)
# Out:
# Number 42 is even

# %% [markdown]
# ## Exercise 4
#
# Write a piece of code that checks whether a number is divisible by 2, 3, 5 and 7.

# %% [markdown]
# A possible solution follows:

# %%
num = 42
if num % 2 == 0:
    print("Number ", num, "is divisible by 2.")
if num % 3 == 0:
    print("Number ", num, "is divisible by 3.")
if num % 5 == 0:
    print("Number ", num, "is divisible by 5.")
if num % 7 == 0:
    print("Number ", num, "is divisible by 7.")
# Out:
# Number  42 is divisible by 2.
# Number  42 is divisible by 3.
# Number  42 is divisible by 7.

# %% [markdown]
# ## Exercise 5
#
# Write a piece of code that checks whether a number is odd or even. Print a message informing the user.
# If odd, check whether the number is divisible by 5. Print a message informing the user.
# If even, check whether the number is divisible by 3. Print a message informing the user.

# %% [markdown]
# A possible solution follows:

# %%
num = 15
if num % 2 == 0:
    print("Number", num, "is even.")
    if num % 3 == 0:
        print("Number", num, "is also divisible by 3.")
    else:
        print("Number", num, "is not divisible by 3.")
else:
    print("Number", num, "is odd.")
    if num % 5 == 0:
        print("Number", num, "is also divisible by 5.")
    else:
        print("Number", num, "is not divisible by 5.")
# Out:
# Number 15 is odd.
# Number 15 is also divisible by 5.

# %% [markdown]
# ## Exercise 6
#
# Write a piece of code that asks the user to insert the dog's age in human's years and calculates a dog's age in dog's years. For the first two years, a dog year is equal to 10.5 human years. After that, each dog year equals 4 human years.

# %% [markdown]
# A possible solution follows:

# %%
h_age = int(input("Input a dog's age in human years: "))
print("Inserted age:", h_age)
if h_age <= 0:
    print("Age must be a positive number.")
else:
    if h_age <= 2:
        d_age = h_age * 10.5
    else:
        d_age = 10.5 + 10.5 + (h_age - 2) * 4
    print("The dog's age in dog's years is:", d_age)
# Out:
# Inserted age: 20
# The dog's age in dog's years is: 93.0
