# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Strings and Lists</b><h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2><h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3><img src="https://introcp.github.io/dist/img/dist/img/logo2.png" width="200px"><br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on strings and lists (no hints)](E06-Python-Exercises-Strings-Lists-student.ipynb)
# - [Notebook with exercises on strings and lists (with pseudocode)](E06-Python-Exercises-Strings-Lists-pseudocode.ipynb)
# - [Notebook with exercises on strings and lists (with solutions)](E06-Python-Exercises-Strings-Lists-solution.ipynb)
