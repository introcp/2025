# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Files</b>
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2><h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3><img src="https://introcp.github.io/dist/img/logo2.png" width="200px"><br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on files (no hints)](E11-Python-Exercises-Files-student.ipynb)
# - [Notebook with exercises on files (with pseudocode)](E11-Python-Exercises-Files-pseudocode.ipynb)
# - [Notebook with exercises on files (with solutions)](E11-Python-Exercises-Files-solution.ipynb)
