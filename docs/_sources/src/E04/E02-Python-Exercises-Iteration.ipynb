# %% [markdown]
# <div align="center">
#
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Iteration</b>
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2>
#
# <h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3>
# <img src="https://introcp.github.io/dist/img/cliente-luiss.png">
#
# <br><br><br>
#
# </div>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on iteration (no hints)](E04-Python-Iteration-Exercises-student.ipynb)
# - [Notebook with exercises on iteration (with pseudocode)](E04-Python-Iteration-Exercises-pseudocode.ipynb)
# - [Notebook with exercises on iteration (with solutions)](E04-Python-Iteration-Exercises-solution.ipynb)
