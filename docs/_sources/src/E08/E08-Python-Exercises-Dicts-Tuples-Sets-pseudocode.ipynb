# %% [markdown]
# # Python: exercises on dictionaries, tuples, and sets
#
# This notebook was generated in **pseudocode** mode.

# %% [markdown]
# ---
# ## Exercise 1: Merge Two Dictionaries

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Create a function `merge_dicts(dict1, dict2)` that combines two dictionaries. If a key exists in both, sum their values.

# %% [markdown]
# #### Your solution

# %%
def merge_dicts(dict1, dict2):
    # Step 1: Create a copy of the first dictionary to avoid modifying the original
    # Step 2: Iterate through each key-value pair in the second dictionary
    # Step 3: For each key in the second dictionary:
    #     - If the key exists in the result, add the values together
    #     - If the key doesn't exist, add the key-value pair to the result
    # Step 4: Return the merged dictionary

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}
result = merge_dicts(dict1, dict2)
print(result)  # Expected: {'a': 1, 'b': 5, 'c': 4}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
dict1 = {'x': 10}
dict2 = {'y': 20, 'x': 5}
result = merge_dicts(dict1, dict2)
print(result)  # Expected: {'x': 15, 'y': 20}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\ndict1 = {'a': 1, 'b': 2}\ndict2 = {'b': 3, 'c': 4}\nresult = merge_dicts(dict1, dict2)\nprint(result)  # Expected: {'a': 1, 'b': 5, 'c': 4}\n\n# Test case 2\ndict1 = {'x': 10}\ndict2 = {'y': 20, 'x': 5}\nresult = merge_dicts(dict1, dict2)\nprint(result)  # Expected: {'x': 15, 'y': 20}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 2: Reverse Lookup

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a function `reverse_lookup(d, value)` that returns all keys from dictionary `d` that map to the given `value`.

# %% [markdown]
# #### Your solution

# %%
def reverse_lookup(d, value):
    # Step 1: Initialize an empty list to store matching keys
    # Step 2: Iterate through each key-value pair in the dictionary
    # Step 3: For each pair, if the value matches the target value:
    #     - Add the key to the result list
    # Step 4: Return the list of matching keys

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
d = {'a': 1, 'b': 2, 'c': 1}
result = reverse_lookup(d, 1)
print(result)  # Expected: ['a', 'c']

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
d = {'x': 'hello', 'y': 'world', 'z': 'hello'}
result = reverse_lookup(d, 'hello')
print(result)  # Expected: ['x', 'z']

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nd = {'a': 1, 'b': 2, 'c': 1}\nresult = reverse_lookup(d, 1)\nprint(result)  # Expected: ['a', 'c']\n\n# Test case 2\nd = {'x': 'hello', 'y': 'world', 'z': 'hello'}\nresult = reverse_lookup(d, 'hello')\nprint(result)  # Expected: ['x', 'z']" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 3: Count Tuple Elements

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a function `count_elements(tup)` that returns a dictionary with counts of each element in the tuple `tup`.

# %% [markdown]
# #### Your solution

# %%
def count_elements(tup):
    # Step 1: Initialize an empty dictionary to store counts
    # Step 2: Iterate through each element in the tuple
    # Step 3: For each element:
    #     - If element exists in dictionary, increment its count
    #     - If element doesn't exist, set its count to 1
    # Step 4: Return the dictionary with element counts

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
tup = (1, 2, 2, 3, 1)
result = count_elements(tup)
print(result)  # Expected: {1: 2, 2: 2, 3: 1}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
tup = ('a', 'b', 'a', 'c', 'b', 'a')
result = count_elements(tup)
print(result)  # Expected: {'a': 3, 'b': 2, 'c': 1}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\ntup = (1, 2, 2, 3, 1)\nresult = count_elements(tup)\nprint(result)  # Expected: {1: 2, 2: 2, 3: 1}\n\n# Test case 2\ntup = ('a', 'b', 'a', 'c', 'b', 'a')\nresult = count_elements(tup)\nprint(result)  # Expected: {'a': 3, 'b': 2, 'c': 1}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 4: Set Intersection

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Implement a function `intersect(s1, s2)` that returns the intersection of two sets `s1` and `s2`.

# %% [markdown]
# #### Your solution

# %%
def intersect(s1, s2):
    # Step 1: Initialize an empty set to store common elements
    # Step 2: Iterate through each element in the first set
    # Step 3: For each element, if it's also in the second set:
    #     - Add it to the result set
    # Step 4: Return the intersection set
    # Alternative: Use built-in set intersection operation (s1 & s2)

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
s1 = {1, 2, 3}
s2 = {2, 3, 4}
result = intersect(s1, s2)
print(result)  # Expected: {2, 3}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
s1 = {'a', 'b', 'c'}
s2 = {'b', 'c', 'd'}
result = intersect(s1, s2)
print(result)  # Expected: {'b', 'c'}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\ns1 = {1, 2, 3}\ns2 = {2, 3, 4}\nresult = intersect(s1, s2)\nprint(result)  # Expected: {2, 3}\n\n# Test case 2\ns1 = {'a', 'b', 'c'}\ns2 = {'b', 'c', 'd'}\nresult = intersect(s1, s2)\nprint(result)  # Expected: {'b', 'c'}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 5: Remove Duplicates

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a function `remove_duplicates(lst)` that returns a list without any duplicates using a set.

# %% [markdown]
# #### Your solution

# %%
def remove_duplicates(lst):
    # Step 1: Convert the list to a set (automatically removes duplicates)
    # Step 2: Convert the set back to a list
    # Step 3: Return the list without duplicates
    # Note: Order may not be preserved

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
lst = [1, 2, 2, 3, 4, 4, 5]
result = remove_duplicates(lst)
print(result)  # Expected: [1, 2, 3, 4, 5]

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
lst = ['a', 'b', 'a', 'c', 'b']
result = remove_duplicates(lst)
print(result)  # Expected: ['a', 'b', 'c'] (order may vary)

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nlst = [1, 2, 2, 3, 4, 4, 5]\nresult = remove_duplicates(lst)\nprint(result)  # Expected: [1, 2, 3, 4, 5]\n\n# Test case 2\nlst = ['a', 'b', 'a', 'c', 'b']\nresult = remove_duplicates(lst)\nprint(result)  # Expected: ['a', 'b', 'c'] (order may vary)" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 6: Tuple to Dictionary

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Create a function `tuple_to_dict(tup)` that turns a tuple of `(key, value)` pairs into a dictionary.

# %% [markdown]
# #### Your solution

# %%
def tuple_to_dict(tup):
    # Step 1: Initialize an empty dictionary
    # Step 2: Iterate through each pair in the tuple
    # Step 3: For each pair (key, value):
    #     - Add the key-value pair to the dictionary
    # Step 4: Return the dictionary
    # Alternative: Use dict() constructor directly

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
tup = (('a', 1), ('b', 2))
result = tuple_to_dict(tup)
print(result)  # Expected: {'a': 1, 'b': 2}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
tup = (('x', 10), ('y', 20), ('z', 30))
result = tuple_to_dict(tup)
print(result)  # Expected: {'x': 10, 'y': 20, 'z': 30}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\ntup = (('a', 1), ('b', 2))\nresult = tuple_to_dict(tup)\nprint(result)  # Expected: {'a': 1, 'b': 2}\n\n# Test case 2\ntup = (('x', 10), ('y', 20), ('z', 30))\nresult = tuple_to_dict(tup)\nprint(result)  # Expected: {'x': 10, 'y': 20, 'z': 30}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 7: Value Switch in Dictionary

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a function `switch_values(d)` that switches the keys and values in a dictionary. Assume all values are unique.

# %% [markdown]
# #### Your solution

# %%
def switch_values(d):
    # Step 1: Initialize an empty dictionary for the result
    # Step 2: Iterate through each key-value pair in the original dictionary
    # Step 3: For each pair:
    #     - Use the original value as the new key
    #     - Use the original key as the new value
    # Step 4: Return the switched dictionary

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
d = {'a': 1, 'b': 2}
result = switch_values(d)
print(result)  # Expected: {1: 'a', 2: 'b'}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
d = {'name': 'John', 'age': 25}
result = switch_values(d)
print(result)  # Expected: {'John': 'name', 25: 'age'}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nd = {'a': 1, 'b': 2}\nresult = switch_values(d)\nprint(result)  # Expected: {1: 'a', 2: 'b'}\n\n# Test case 2\nd = {'name': 'John', 'age': 25}\nresult = switch_values(d)\nprint(result)  # Expected: {'John': 'name', 25: 'age'}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 8: Dictionary of Squares

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Create a function `squares(n)` that returns a dictionary of numbers from 1 to `n` where the keys are numbers and the values are their squares.

# %% [markdown]
# #### Your solution

# %%
def squares(n):
    # Step 1: Initialize an empty dictionary
    # Step 2: Iterate through numbers from 1 to n (inclusive)
    # Step 3: For each number:
    #     - Use the number as the key
    #     - Use the square of the number as the value
    # Step 4: Return the dictionary

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
result = squares(5)
print(result)  # Expected: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
result = squares(3)
print(result)  # Expected: {1: 1, 2: 4, 3: 9}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nresult = squares(5)\nprint(result)  # Expected: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}\n\n# Test case 2\nresult = squares(3)\nprint(result)  # Expected: {1: 1, 2: 4, 3: 9}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 9: Set Difference

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a function `difference(s1, s2)` that returns a set of elements that are only in the first set `s1` but not in the second set `s2`.

# %% [markdown]
# #### Your solution

# %%
def difference(s1, s2):
    # Step 1: Initialize an empty set for the result
    # Step 2: Iterate through each element in the first set
    # Step 3: For each element, if it's NOT in the second set:
    #     - Add it to the result set
    # Step 4: Return the difference set
    # Alternative: Use built-in set difference operation (s1 - s2)

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
s1 = {1, 2, 3, 4}
s2 = {3, 4, 5, 6}
result = difference(s1, s2)
print(result)  # Expected: {1, 2}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
s1 = {'a', 'b', 'c'}
s2 = {'b', 'd'}
result = difference(s1, s2)
print(result)  # Expected: {'a', 'c'}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\ns1 = {1, 2, 3, 4}\ns2 = {3, 4, 5, 6}\nresult = difference(s1, s2)\nprint(result)  # Expected: {1, 2}\n\n# Test case 2\ns1 = {'a', 'b', 'c'}\ns2 = {'b', 'd'}\nresult = difference(s1, s2)\nprint(result)  # Expected: {'a', 'c'}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 10: Count Vowels

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Create a function `count_vowels(s)` that counts and returns a dictionary with vowels as keys and their counts in the string `s` as values.

# %% [markdown]
# #### Your solution

# %%
def count_vowels(s):
    # Step 1: Define a set of vowels (a, e, i, o, u)
    # Step 2: Initialize an empty dictionary to store vowel counts
    # Step 3: Iterate through each character in the string (convert to lowercase)
    # Step 4: For each character, if it's a vowel:
    #     - If vowel exists in dictionary, increment its count
    #     - If vowel doesn't exist, set its count to 1
    # Step 5: Return the vowel count dictionary

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
result = count_vowels('hello world')
print(result)  # Expected: {'e': 1, 'o': 2}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
result = count_vowels('programming')
print(result)  # Expected: {'o': 1, 'a': 1, 'i': 1}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nresult = count_vowels('hello world')\nprint(result)  # Expected: {'e': 1, 'o': 2}\n\n# Test case 2\nresult = count_vowels('programming')\nprint(result)  # Expected: {'o': 1, 'a': 1, 'i': 1}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 11: Find Max Value

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a function `find_max(d)` that returns the key with the maximum value in the dictionary `d`.

# %% [markdown]
# #### Your solution

# %%
def find_max(d):
    # Step 1: Initialize variables to track the maximum value and corresponding key
    # Step 2: Iterate through each key-value pair in the dictionary
    # Step 3: For each pair, if this value is greater than the current maximum:
    #     - Update both the maximum value and the corresponding key
    # Step 4: Return the key with the maximum value
    # Alternative: Use max() function with key parameter

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
d = {'a': 5, 'b': 12, 'c': 3}
result = find_max(d)
print(result)  # Expected: 'b'

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
d = {'x': 100, 'y': 50, 'z': 200}
result = find_max(d)
print(result)  # Expected: 'z'

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nd = {'a': 5, 'b': 12, 'c': 3}\nresult = find_max(d)\nprint(result)  # Expected: 'b'\n\n# Test case 2\nd = {'x': 100, 'y': 50, 'z': 200}\nresult = find_max(d)\nprint(result)  # Expected: 'z'" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 12: Unique Characters

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Create a function `unique_chars(s)` that returns a set of unique characters in the string `s`.

# %% [markdown]
# #### Your solution

# %%
def unique_chars(s):
    # Step 1: Convert the string to a set (automatically removes duplicates)
    # Step 2: Return the set of unique characters

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
result = unique_chars('hello')
print(result)  # Expected: {'e', 'h', 'l', 'o'}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
result = unique_chars('programming')
print(result)  # Expected: {'p', 'r', 'o', 'g', 'a', 'm', 'i', 'n'}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nresult = unique_chars('hello')\nprint(result)  # Expected: {'e', 'h', 'l', 'o'}\n\n# Test case 2\nresult = unique_chars('programming')\nprint(result)  # Expected: {'p', 'r', 'o', 'g', 'a', 'm', 'i', 'n'}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 13: Key Multiplication

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a function `multiply_keys(d, factor)` that returns a new dictionary where each key is multiplied by a `factor`.

# %% [markdown]
# #### Your solution

# %%
def multiply_keys(d, factor):
    # Step 1: Initialize an empty dictionary for the result
    # Step 2: Iterate through each key-value pair in the original dictionary
    # Step 3: For each pair:
    #     - Multiply the key by the factor
    #     - Use the multiplied key with the original value in the result dictionary
    # Step 4: Return the new dictionary

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
d = {1: 100, 2: 200}
result = multiply_keys(d, 2)
print(result)  # Expected: {2: 100, 4: 200}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
d = {3: 'a', 5: 'b'}
result = multiply_keys(d, 10)
print(result)  # Expected: {30: 'a', 50: 'b'}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nd = {1: 100, 2: 200}\nresult = multiply_keys(d, 2)\nprint(result)  # Expected: {2: 100, 4: 200}\n\n# Test case 2\nd = {3: 'a', 5: 'b'}\nresult = multiply_keys(d, 10)\nprint(result)  # Expected: {30: 'a', 50: 'b'}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 14: Set Complement

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Implement a function `complement(full_set, sub_set)` that returns the set of elements in `full_set` that are not in `sub_set`.

# %% [markdown]
# #### Your solution

# %%
def complement(full_set, sub_set):
    # Step 1: Initialize an empty set for the result
    # Step 2: Iterate through each element in the full set
    # Step 3: For each element, if it's NOT in the subset:
    #     - Add it to the result set
    # Step 4: Return the complement set
    # Alternative: Use built-in set difference operation (full_set - sub_set)

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
full_set = {1, 2, 3, 4, 5}
sub_set = {2, 4}
result = complement(full_set, sub_set)
print(result)  # Expected: {1, 3, 5}

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
full_set = {'a', 'b', 'c', 'd'}
sub_set = {'b', 'd'}
result = complement(full_set, sub_set)
print(result)  # Expected: {'a', 'c'}

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nfull_set = {1, 2, 3, 4, 5}\nsub_set = {2, 4}\nresult = complement(full_set, sub_set)\nprint(result)  # Expected: {1, 3, 5}\n\n# Test case 2\nfull_set = {'a', 'b', 'c', 'd'}\nsub_set = {'b', 'd'}\nresult = complement(full_set, sub_set)\nprint(result)  # Expected: {'a', 'c'}" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 15: Count Keys Starting With

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a function `count_keys_starting_with(d, char)` that returns the count of keys in dictionary `d` that start with `char`.

# %% [markdown]
# #### Your solution

# %%
def count_keys_starting_with(d, char):
    # Step 1: Initialize a counter to 0
    # Step 2: Iterate through each key in the dictionary
    # Step 3: For each key:
    #     - Convert key to string (in case it's not already a string)
    #     - Check if the first character matches the target character
    #     - If it matches, increment the counter
    # Step 4: Return the counter

# %% [markdown]
# #### Test your solution

# %%
# Test case 1
d = {'apple': 1, 'banana': 2, 'apricot': 3, 'cherry': 4}
result = count_keys_starting_with(d, 'a')
print(result)  # Expected: 2

# %% [markdown]
# #### Test your solution

# %%
# Test case 2
d = {'hello': 1, 'world': 2, 'python': 3}
result = count_keys_starting_with(d, 'h')
print(result)  # Expected: 1

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n# Test case 1\nd = {'apple': 1, 'banana': 2, 'apricot': 3, 'cherry': 4}\nresult = count_keys_starting_with(d, 'a')\nprint(result)  # Expected: 2\n\n# Test case 2\nd = {'hello': 1, 'world': 2, 'python': 3}\nresult = count_keys_starting_with(d, 'h')\nprint(result)  # Expected: 1" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
