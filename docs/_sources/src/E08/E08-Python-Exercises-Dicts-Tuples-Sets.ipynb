# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Dictionaries, Tuples and Sets</b><h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2><h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3><img src="https://introcp.github.io/dist/img/dist/img/logo2.png" width="200px"><br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on dictionaries, tuples, and sets (no hints)](E08-Python-Exercises-Dicts-Tuples-Sets-student.ipynb)
# - [Notebook with exercises on dictionaries, tuples, and sets (with pseudocode)](E08-Python-Exercises-Dicts-Tuples-Sets-pseudocode.ipynb)
# - [Notebook with exercises on dictionaries, tuples, and sets (with solutions)](E08-Python-Exercises-Dicts-Tuples-Sets-solution.ipynb)
