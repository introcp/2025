# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Iteration</b>
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2><h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3><img src="https://introcp.github.io/dist/img/logo2.png" width="200px"><br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on iteration (no hints)](E05-Python-Iteration-Exercises-student.ipynb)
# - [Notebook with exercises on iteration (with pseudocode)](E05-Python-Iteration-Exercises-pseudocode.ipynb)
# - [Notebook with exercises on iteration (with solutions)](E05-Python-Iteration-Exercises-solution.ipynb)
